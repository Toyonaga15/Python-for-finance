# %% [markdown]
# <a href="https://colab.research.google.com/github/Toyonaga15/Python-for-finance/blob/main/Stock_Market_Analysis_of_a_Given_Month.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting yfinance
#   Downloading yfinance-0.2.9-py2.py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 KB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.8/dist-packages (from yfinance) (4.9.2)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.8/dist-packages (from yfinance) (1.4.4)
# Collecting cryptography>=3.3.2
#   Downloading cryptography-39.0.0-cp36-abi3-manylinux_2_28_x86_64.whl (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 44.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.8/dist-packages (from yfinance) (1.21.6)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.8/dist-packages (from yfinance) (1.3.5)
# Collecting html5lib>=1.1
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 KB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.8/dist-packages (from yfinance) (0.0.11)
# Collecting requests>=2.26
#   Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.8/dist-packages (from yfinance) (2022.7)
# Collecting beautifulsoup4>=4.11.1
#   Downloading beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 KB 5.4 MB/s eta 0:00:00
# Collecting frozendict>=2.3.4
#   Downloading frozendict-2.3.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 KB 5.5 MB/s eta 0:00:00
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.8/dist-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.8/dist-packages (from html5lib>=1.1->yfinance) (1.15.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.8/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.26->yfinance) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.26->yfinance) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)
# Installing collected packages: soupsieve, requests, html5lib, frozendict, cryptography, beautifulsoup4, yfinance
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
#   Attempting uninstall: html5lib
#     Found existing installation: html5lib 1.0.1
#     Uninstalling html5lib-1.0.1:
#       Successfully uninstalled html5lib-1.0.1
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed beautifulsoup4-4.11.1 cryptography-39.0.0 frozendict-2.3.4 html5lib-1.1 requests-2.28.2 soupsieve-2.3.2.post1 yfinance-0.2.9

# %%
# Importing necessary libraries
import yfinance as yf
import pandas as pd

# %%
#Asking user to input the stock name and the start and end years of analysis
asset = input('Enter the stock name according to yahoo finance: ').strip().upper()
start_year = int(input('Enter the starting year of analysis: '))
end_year = int(input('Enter the ending year of analysis: '))
month_number = int(input(f'Which month of the year do you want to analyze? (ex:1, 2, 3...): '))

data = yf.download(asset, start=f'{start_year}-01-01', end=f'{end_year}-12-31', interval='1mo')

data_yf = pd.DataFrame(data)
# Out:
# Enter the stock name according to yahoo finance: ^GSPC
# Enter the starting year of analysis: 2000
# Enter the ending year of analysis: 2023
# Which month of the year do you want to analyze? (ex:1, 2, 3...): 2
# [*********************100%***********************]  1 of 1 completed

# %%
# Creating a dataframe and adding columns with percentage change

data_yf = pd.DataFrame(data)
data_yf['Closing %'] = data_yf['Close'].pct_change()*100
data_yf['Opening %'] = ((data_yf['Open']-data_yf['Close'].shift(1))/data_yf['Close'])*100
data_yf['Max %'] = ((data_yf['High']-data_yf['Close'].shift(1))/data_yf['Close'])*100
data_yf['Min %'] = ((data_yf['Low']-data_yf['Close'].shift(1))/data_yf['Close'])*100

# Filling the missing values in the 'Closing %', 'Opening %', 'Max %' and 'Min %' columns with the mean of the respective columns. 
if pd.isnull(data_yf['Closing %'].iloc[0]):
    data_yf['Closing %'].iloc[0] = data_yf['Closing %'].mean()
    data_yf['Opening %'].iloc[0] = data_yf['Opening %'].mean()
    data_yf['Max %'].iloc[0] = data_yf['Max %'].mean()
    data_yf['Min %'].iloc[0] = data_yf['Min %'].mean()

# Changing the index to date
data_yf.index = pd.to_datetime(data_yf.index.date)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
# Selecting only the data of the selected month number
month_data = data[data.index.month == month_number]
month_data = pd.DataFrame(month_data)

df = month_data
df
# Out:
#                    Open         High          Low        Close    Adj Close  \
# 2000-02-01  1394.459961  1444.550049  1325.069946  1366.420044  1366.420044
# 2001-02-01  1366.010010  1376.380005  1215.439941  1239.939941  1239.939941
# 2002-02-01  1130.199951  1130.199951  1074.359985  1106.729980  1106.729980
# 2003-02-01   855.700012   864.640015   806.289978   841.150024   841.150024
# 2004-02-01  1131.130005  1158.979980  1124.439941  1144.939941  1144.939941
# 2005-02-01  1181.270020  1212.439941  1180.949951  1203.599976  1203.599976
# 2006-02-01  1280.079956  1297.569946  1253.609985  1280.660034  1280.660034
# 2007-02-01  1437.900024  1461.569946  1389.420044  1406.819946  1406.819946
# 2008-02-01  1378.599976  1396.020020  1316.750000  1330.630005  1330.630005
# 2009-02-01   823.090027   875.010010   734.520020   735.090027   735.090027
# 2010-02-01  1073.890015  1112.420044  1044.500000  1104.489990  1104.489990
# 2011-02-01  1289.140015  1344.069946  1289.140015  1327.219971  1327.219971
# 2012-02-01  1312.449951  1378.040039  1312.449951  1365.680054  1365.680054
# 2013-02-01  1498.109985  1530.939941  1485.010010  1514.680054  1514.680054
# 2014-02-01  1782.680054  1867.920044  1737.920044  1859.449951  1859.449951
# 2015-02-01  1996.670044  2119.590088  1980.900024  2104.500000  2104.500000
# 2016-02-01  1936.939941  1962.959961  1810.099976  1932.229980  1932.229980
# 2017-02-01  2285.590088  2371.540039  2271.649902  2363.639893  2363.639893
# 2018-02-01  2816.449951  2835.959961  2532.689941  2713.830078  2713.830078
# 2019-02-01  2702.320068  2813.489990  2681.830078  2784.489990  2784.489990
# 2020-02-01  3235.659912  3393.520020  2855.840088  2954.219971  2954.219971
# 2021-02-01  3731.169922  3950.429932  3725.620117  3811.149902  3811.149902
# 2022-02-01  4519.569824  4595.310059  4114.649902  4373.939941  4373.939941
#
#                   Volume  Closing %  Opening %     Max %      Min %
# 2000-02-01   20912000000  -2.010808   0.000000  3.665790  -5.078235
# 2001-02-01   21644400000  -9.229074   0.000000  0.836330 -12.143336
# 2002-02-01   26047600000  -2.076621   0.000000  0.000000  -5.045491
# 2003-02-01   25235300000  -1.700361   0.000000  1.062831  -5.874105
# 2004-02-01   27985600000   1.220897   0.000000  2.432440  -0.584316
# 2005-02-01   29297410000   1.890335   0.000000  2.589724  -0.026593
# 2006-02-01   42859940000   0.045316   0.000000  1.365701  -2.066901
# 2007-02-01   51844990000  -2.184618  -0.024166  1.658347  -3.470234
# 2008-02-01   78536130000  -3.476119   0.003752  1.312910  -4.644420
# 2009-02-01  124492210000 -10.993120  -0.379542  6.683536 -12.428408
# 2010-02-01   84561340000   2.851369   0.001813  3.490303  -2.659145
# 2011-02-01   59223660000   3.195656   0.227545  4.366266   0.227545
# 2012-02-01   78385710000   4.058946   0.002923  4.805665   0.002923
# 2013-02-01   69273480000   1.106065   0.000000  2.167452  -0.864868
# 2014-02-01   69725590000   4.311703   0.004845  4.588996  -2.402319
# 2015-02-01   68775560000   5.489251   0.079831  5.920651  -0.669516
# 2016-02-01   93049560000  -0.412836  -0.170790  1.175842  -6.735224
# 2017-02-01   69260940000   3.719816   0.284306  3.920645  -0.305470
# 2018-02-01   79933970000  -3.894737  -0.271207  0.447703 -10.727279
# 2019-02-01   70638770000   2.972889  -0.063927  3.928543  -0.799788
# 2020-02-01   84436590000  -8.411048   0.343234  5.686780 -12.513622
# 2021-02-01   99082320000   2.609145   0.444221  6.197341   0.298601
# 2022-02-01   92667710000  -3.136049   0.091908  1.823533  -9.165647

# %%
# Creating an empty list to store the result of closing percentage change (positive or negative)
closing_result = []

# Loop to check if the closing percentage change is positive or negative
for i in df['Closing %']:
  if i > 0:
    closing_result.append('Positive')
  else:
    closing_result.append('Negative')

# Adding a new column to the dataframe with the closing result
df['Closing Result'] = closing_result

# Creating an empty list to store the result of opening percentage change (positive or negative)
opening_result = []

# Loop to check if the opening percentage change is positive or negative

for i in df['Opening %']:
  if i > 0:
    opening_result.append('Positive')
  else:
    opening_result.append('Negative')

# Adding a new column to the dataframe with the opening result
df['Opening Result'] = opening_result

# Counting the number of positive closing results and dividing by the total number of data points to get the probability
positive_closing_count = 0
for i in df['Closing Result']:
  if i =='Positive':
    positive_closing_count += 1
    prob_closing = (positive_closing_count/len(df['Closing Result']))*100
    


# Dividing the count of positive closing results by the total number of data points to get the probability of a positive closing result
prob_closing = (positive_closing_count / len(df['Closing Result'])) * 100

# Counting the number of positive opening results and dividing by the total number of data points to get the probability

positive_opening_count = 0
for i in df['Opening Result']:
  if i =='Positive':
    positive_opening_count += 1
    prob_opening = (positive_opening_count / len(df['Opening Result'])) * 100

# Calculating the mean of the max and min percentage changes
mean_max = sum(df['Max %']) / len(df['Max %'])
mean_min = sum(df['Min %']) / len(df['Min %'])

# Printing the final result
print(f'''Statistically, the stock {asset} opened {round(prob_opening,2)}% of the times in high and closed
{round(prob_closing,2)}% of the times in high in the selected month.''')
print(f'The mean of the max percentage changes is {round(mean_max,2)}% and the mean of the min percentage changes is {round(mean_min,2)}%')
# Out:
# Statistically, the stock ^GSPC opened 43.48% of the times in high and closed
# 52.17% of the times in high in the selected month.
# The mean of the max percentage changes is 3.05% and the mean of the min percentage changes is -4.25%
